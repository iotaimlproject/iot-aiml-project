# %% [markdown]
# # ANN Future OEE Forecasting
#
# 4 separate horizon models for OEE prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/syn_timeseries_oee.csv')
print(f'Shape: {df.shape}')
display(df.head())
print(f'\nNull counts:\n{df.isnull().sum()}')
# Out:
# Shape: (19520, 12)
#              timestamp    rpm  availability  performance  quality  \
# 0  2026-01-01 00:00:00  400.0          98.0         0.00    95.00
# 1  2026-01-01 00:01:00  398.7          98.1        82.45    95.32
# 2  2026-01-01 00:02:00  395.3          98.2        76.41    96.08
# 3  2026-01-01 00:03:00  396.3          98.3        80.51    95.85
# 4  2026-01-01 00:04:00  393.2          98.4        77.46    96.12
#
#    current_oee  downtime_minutes  target_oee_30m  target_oee_1h  \
# 0         0.00               0.0           67.47          69.88
# 1        77.10               0.0           64.96          69.15
# 2        72.10               0.0           66.26          70.09
# 3        75.86               0.0           66.65          70.48
# 4        73.26               0.0           66.61          68.95
#
#    target_oee_2h  target_oee_6h  target_oee_8h
# 0          82.61          97.39          82.68
# 1          81.32          92.63          84.99
# ...

# %%
features = ['rpm', 'availability', 'performance', 'quality', 'current_oee', 'downtime_minutes']

targets = {
    '30m': 'target_oee_30m',
    '1h':  'target_oee_1h',
    '2h':  'target_oee_2h',
    '6h':  'target_oee_6h',
    '8h':  'target_oee_8h',
}

X = df[features].values

n = len(df)
train_end = int(0.8 * n)
val_end   = int(0.9 * n)

X_train, X_val, X_test = X[:train_end], X[train_end:val_end], X[val_end:]

scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train)
X_val_s   = scaler.transform(X_val)
X_test_s  = scaler.transform(X_test)

print(f'Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}')
# Out:
# Train: 15616, Val: 1952, Test: 1952

# %%
def build_oee_model():
    model = Sequential([
        Input(shape=(6,)),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(16, activation='relu'),
        Dense(1, activation='linear')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])
    return model

# %%
results = []
histories = {}
models = {}
y_test_dict = {}
y_pred_dict = {}

for horizon, col in targets.items():
    print(f'\n{"="*50}')
    print(f'Training model for horizon: {horizon}')
    print(f'{"="*50}')

    y = df[col].values
    y_train, y_val, y_test = y[:train_end], y[train_end:val_end], y[val_end:]
    y_test_dict[horizon] = y_test

    model = build_oee_model()
    es = EarlyStopping(patience=10, restore_best_weights=True)

    h = model.fit(
        X_train_s, y_train,
        validation_data=(X_val_s, y_val),
        epochs=100,
        batch_size=32,
        callbacks=[es],
        verbose=1
    )

    histories[horizon] = h
    models[horizon] = model

    y_pred = model.predict(X_test_s).flatten()
    y_pred_dict[horizon] = y_pred

    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mape = np.mean(np.abs((y_test - y_pred) / (y_test + 1e-8))) * 100

    results.append({'Horizon': horizon, 'R²': r2, 'MAE': mae, 'RMSE': rmse, 'MAPE (%)': mape})

    print(f'\nHorizon {horizon} — R²: {r2:.4f}, MAE: {mae:.4f}, RMSE: {rmse:.4f}, MAPE: {mape:.2f}%')
# Out:
# ...
# Training model for horizon: 30m
# ...
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/100
#   1/488 ━━━━━━━━━━━━━━━━━━━━ 17:10 2s/step - loss: 4827.5952 - mae: 68.5159
#  27/488 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4662.9584 - mae: 67.3389
#  52/488 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4569.4878 - mae: 66.6290
#  76/488 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4454.8327 - mae: 65.7253
#  98/488 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4303.4008 - mae: 64.4137
# 125/488 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4064.2703 - mae: 62.0000
# 149/488 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3843.1324 - mae: 59.5425
# 174/488 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3627.1622 - mae: 57.0320
# 199/488 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3430.6943 - mae: 54.6708
# ...

# %%
import os, joblib

os.makedirs('models', exist_ok=True)

for horizon, model in models.items():
    path = f'models/ann_oee_{horizon}.keras'
    model.save(path)
    print(f'Saved {path}')

joblib.dump(scaler, 'models/scaler.pkl')
print('Saved models/scaler.pkl')
# Out:
# Saved models/ann_oee_30m.keras
# Saved models/ann_oee_1h.keras
# Saved models/ann_oee_2h.keras
# Saved models/ann_oee_6h.keras
# Saved models/ann_oee_8h.keras
# Saved models/scaler.pkl

# %%
results_df = pd.DataFrame(results).set_index('Horizon')
print('\n' + '='*60)
print('MODEL PERFORMANCE SUMMARY')
print('='*60)
print(results_df.to_string())
print('='*60)
# Out:
# ...
# MODEL PERFORMANCE SUMMARY
# ...
#                R²        MAE       RMSE   MAPE (%)
# Horizon
# 30m      0.839950   3.661047   4.644081   5.507296
# 1h       0.790316   4.296679   5.420842   6.384154
# 2h       0.648474   5.922629   7.222887   8.660956
# 6h      -0.179496  11.294973  13.031368  16.559041
# 8h      -0.494024  12.826583  14.434982  18.583110
# ...

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.flatten()

for i, (horizon, _) in enumerate(targets.items()):
    ax = axes[i]
    ax.scatter(y_test_dict[horizon], y_pred_dict[horizon], alpha=0.5, s=10)
    lims = [min(y_test_dict[horizon]), max(y_test_dict[horizon])]
    ax.plot(lims, lims, 'r--', lw=1)
    ax.set_xlabel('Actual')
    ax.set_ylabel('Predicted')
    ax.set_title(f'Horizon {horizon}')
    ax.axis('square')

plt.suptitle('Actual vs Predicted OEE — All Horizons', fontsize=14)
# Hide the 6th subplot (only 5 models)
axes[5].set_visible(False)
plt.tight_layout()
plt.show()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

ax1.bar(results_df.index, results_df['R²'], color='steelblue')
ax1.set_title('R² Score by Horizon')
ax1.set_ylabel('R²')
ax1.axhline(0, color='gray', ls='--')

ax2.bar(results_df.index, results_df['MAE'], color='coral')
ax2.set_title('MAE by Horizon')
ax2.set_ylabel('MAE')

# Hide the 6th subplot (only 5 models)
axes[5].set_visible(False)
plt.tight_layout()
plt.show()

fig, ax = plt.subplots(figsize=(12, 4))
ax.plot(y_test_dict['1h'][:200], label='Actual', alpha=0.8)
ax.plot(y_pred_dict['1h'][:200], label='Predicted', alpha=0.8)
ax.set_title('Actual vs Predicted OEE — 1h Horizon (first 200 test points)')
ax.set_xlabel('Sample')
ax.set_ylabel('OEE')
ax.legend()
# Hide the 6th subplot (only 5 models)
axes[5].set_visible(False)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 5, figsize=(20, 4))

for i, (horizon, model) in enumerate(models.items()):
    w = model.layers[0].get_weights()[0]
    importance = np.mean(np.abs(w), axis=1)
    axes[i].barh(features, importance, color='teal')
    axes[i].set_title(f'Horizon {horizon}')
    axes[i].set_xlabel('Mean |Weight|')

plt.suptitle('Feature Importance Proxy — First Layer Weight Magnitudes', fontsize=14)
plt.tight_layout()
plt.show()
